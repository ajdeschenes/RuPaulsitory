# %%
import pandas as pd
from pprint import pprint

# %%
csvfile = pd.read_csv('Resources/zips_and_hoods_from_chicagorealestatelocal.com.csv', header=None, delimiter=',')
print(str(csvfile.iloc[1]))
df = pd.DataFrame(csvfile)
#print(df)
mylist = []
zips = []
hoods = []
mylist = df.iloc[:,0]
#print(mylist)
for row in mylist:
    zip = row.rsplit(' ')
    zips.append(zip[0])
    hood = row.split(' ',1)
    hoods.append(hood)
#print(zips)
zips[0] = '60601'
for zip in zips:
    print(zip)
pprint(hoods)
df['Zip Code']=zips
#print(df['Zip Code'])
#print(df.head())
df[['Zip Code', 'Neighborhoods']] = df[0].str.split(' ',1,expand=True)
# df[['V','allele']] = df['V'].str.split('-',expand=True)
#print(df.head())
# Out:
# 0    60602 Loop
# Name: 1, dtype: object
# 60601
# 60602
# 60603
# 60604
# 60605
# 60606
# 60607
# 60608
# 60609
# 60610
# 60611
# 60612
# 60613
# 60614
# 60615
# 60616
# 60617
# 60618
# 60619
# 60620
# 60621
# 60622
# 60623
# 60624
# 60625
# 60626
# 60627
# 60628
# 60629
# 60630
# 60631
# 60632
# 60633
# 60634
# 60635
# 60636
# 60637
# 60638
# 60639
# 60640
# 60641
# 60642
# 60643
# 60644
# 60645
# 60646
# 60647
# 60649
# 60651
# 60652
# 60653
# 60655
# 60656
# 60657
# 60659
# 60660
# 60661
# 60664
# 60666
# 60680
# 60681
# [['60601\xa0Loop\xa0'],
#  ['60602', 'Loop\xa0'],
#  ['60603', 'Loop\xa0'],
#  ['60604', 'Loop\xa0'],
#  ['60605', 'Loop, Near South Side\xa0'],
#  ['60606', 'Loop, Near West Side\xa0'],
#  ['60607', 'Loop, Near West Side, Near South Side\xa0'],
#  ['60608',
#   'Bridgeport, Lower West Side (Pilsen), McKinley Park, Near West Side, North '
#   'Lawndale, South Lawndale\xa0'],
#  ['60609',
#   'Armour Square, Bridgeport, Douglas, Fuller Park, Gage Park, Grand '
# ...

# %%
csvfile2 = pd.read_csv('Resources/zips_in_order.csv', delimiter = ',', header=None)
print(csvfile2)
df2 = pd.DataFrame(csvfile2)
zips = []
for row in df2:
    zip = str(row).rsplit('          ')
    zips.append(zip)
print(zips)

Neighborhoods
Loop
Loop
Loop
Loop
Loop, Near South Side
Loop, Near West Side
Loop, Near West Side, Near South Side
Bridgeport, Lower West Side (Pilsen), McKinley Park, Near West Side, North Lawndale, South Lawndale
Armour Square, Bridgeport, Douglas, Fuller Park, Gage Park, Grand Boulevard, McKinley Park, New City, Washington Park
Near North Side, Near West Side
Near North Side
Near West Side, West Town
Lakeview, North Center, Uptown
Lincoln Park, Logan Square
Grand Boulevard, Hyde Park, Kenwood, Washington Park
Armour Square, Bridgeport, Douglas,Lower West Side (Pilsen), Near South Side
Avalon Park, Calumet Heights, East Side, South Chicago, South Deering
Avondale, Irving Park, North Center
Avalon Park, Burnside, Calumet Heights, Chatham, Greater Grand Crossing, Roseland, South Shore
Auburn Gresham, Beverly, Chatham, Greater Grand Crossing, Roseland, Washington Heights
Englewood, Greater Grand Crossing, Washington Park
Humboldt Park, Logan Square, Near North Side, West Town
Humboldt Park, Logan Square, Near North Side, West Town
East Garfield Park, Humboldt Park, North Lawndale, West Garfield Park
Albany Park, Lincoln Square, North Park
Rogers Park
Riverdale Chicago
Pullman, Roseland, Washington Heights, West Pullman
Chicago Lawn, Clearing, Gage Park, Garfield Ridge, West Elsdon, West Lawn
Albany Park, Forest Glen, Irving Park, Jefferson Park, Portage Park
Edison Park, Norwood Park
Archer Heights, Brighton Park, Gage Park, Garfield Ridge, West Elsdon
Hegewisch, South Deering
Belmont Cragin, Dunning, Montclare, Portage Park
Austin, Belmont Cragin, Dunning, Montclare
Chicago Lawn, Gage Park, West Englewood
Greater Grand Crossing, Hyde Park, South Shore, Washington Park, Woodlawn
Clearing, Garfield Ridge
Austin, Belmont Cragin, Hermosa, Humboldt Park, Logan Square
Edgewater, Lincoln Square, Uptown
Avondale, Belmont Cragin, Hermosa, Irving Park, Portage Park
Beverly
Beverly, Morgan Park, Washington Heights, West Pullman
Austin
West Ridge
Forest Glen, Jefferson Park, North Park, Norwood Park
Hermosa, Humboldt Park, Logan Square, West Town
South Shore
Austin, Humboldt Park
Ashburn
Douglas, Grand Boulevard, Kenwood, Oakland
Beverly, Morgan Park, Mount Greenwood
O'Hare
Lakeview, North Center
North Park, West Ridge
Edgewater
Loop, Near West Side
Near West Side
O'Hare
Near West Side
Near West Side

# %%
strings = []
zips = []
for string in df.iloc[:,0]:
    strings.append(string.split(' '))
print(strings)
'''
df2 = pd.DataFrame(strings)
print(df2.head())
zips = df2.iloc[:,0]
print()
print(zips.head(35))
'''
# Out:
# [['60601\xa0Loop\xa0'], ['60602', 'Loop\xa0'], ['60603', 'Loop\xa0'], ['60604', 'Loop\xa0'], ['60605', 'Loop,', 'Near', 'South', 'Side\xa0'], ['60606', 'Loop,', 'Near', 'West', 'Side\xa0'], ['60607', 'Loop,', 'Near', 'West', 'Side,', 'Near', 'South', 'Side\xa0'], ['60608', 'Bridgeport,', 'Lower', 'West', 'Side', '(Pilsen),', 'McKinley', 'Park,', 'Near', 'West', 'Side,', 'North', 'Lawndale,', 'South', 'Lawndale\xa0'], ['60609', 'Armour', 'Square,', 'Bridgeport,', 'Douglas,', 'Fuller', 'Park,', 'Gage', 'Park,', 'Grand', 'Boulevard,', 'McKinley', 'Park,', 'New', 'City,', 'Washington', 'Park\xa0'], ['60610', 'Near', 'North', 'Side,', 'Near', 'West', 'Side\xa0'], ['60611', 'Near', 'North', 'Side\xa0'], ['60612', 'Near', 'West', 'Side,', 'West', 'Town\xa0'], ['60613', 'Lakeview,', 'North', 'Center,', 'Uptown\xa0'], ['60614', 'Lincoln', 'Park,', 'Logan', 'Square\xa0'], ['60615', 'Grand', 'Boulevard,', 'Hyde', 'Park,', 'Kenwood,', 'Washington', 'Park\xa0'], ['60616', 'Armour', 'Square,', 'Br
# ...

# %%
csvfile2 = pd.read_csv('Resources/zips_in_order.csv', delimiter=',',header=None)

# %%
print(csvfile2)
df3 = pd.DataFrame
df3 = csvfile2
print(df3.iloc[:])
zips = []
cleanzips = []
zips = df3.iloc[:]
print(zips)
for zip in zips:
    zip = str(zip).split('        ')
    cleanzips.append(zip)
print(cleanzips)
# Out:
#                     0
# 0   0          60601
# 1    1          60602
# 2    2          60603
# 3    3          60604
# 4    4          60605
# 5    5          60606
# 6    6          60607
# 7    7          60608
# 8    8          60609
# 9    9          60610
# 10  10          60611
# 11  11          60612
# 12  12          60613
# 13  13          60614
# 14  14          60615
# 15  15          60616
# 16  16          60617
# 17  17          60618
# 18  18          60619
# 19  19          60620
# 20  20          60621
# 21  21          60622
# 22  22          60623
# 23  23          60624
# 24  24          60625
# 25  25          60626
# 26  26          60627
# 27  27          60628
# 28  28          60629
# 29  29          60630
# ..                ...
# 31  31          60632
# 32  32          60633
# 33  33          60634
# 34  34          60635
# 35  35          60636
# 36  36          60637
# 37  37          60638
# 38  38          60639
# 39  39          60640
# ...
