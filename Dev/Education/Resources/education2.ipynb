# %%
import pandas as pd

# read CPS progress reports (from data.cityofchicago.org) from CSV to DataFrames
cps_11 = pd.DataFrame
cps_11 = pd.read_csv('../Resources/cityofchicago.org/Chicago_Public_Schools_-_Progress_Report_Cards__2011-2012_.csv',delimiter=',')
cps_hs_12 = pd.DataFrame
cps_hs_12 = pd.read_csv('../Resources/cityofchicago.org/cps_hs_progress_report2012-2013.csv', delimiter=',')
cps_es_12 = pd.DataFrame
cps_es_12 = pd.read_csv('../Resources/cityofchicago.org/Chicago_Public_Schools_-_Elementary_School_Progress_Report__2013-2014_.csv',delimiter=',')
cps_hs_13 = pd.DataFrame
cps_hs_13 = pd.read_csv('../Resources/cityofchicago.org/Chicago_Public_Schools_-_High_School_Progress_Report__2013-2014_.csv',delimiter=',')
cps_es_13 = pd.DataFrame
cps_es_13 = pd.read_csv('../Resources/cityofchicago.org/Chicago_Public_Schools_-_Elementary_School_Progress_Report__2013-2014_.csv',delimiter=',')
cps_16 = pd.DataFrame
cps_16 = pd.read_csv('../Resources/cityofchicago.org/Chicago_Public_Schools_-_School_Progress_Reports_SY1617.csv',delimiter=',')
cps_17 = pd.DataFrame
cps_17 = pd.read_csv('../Resources/cityofchicago.org/Chicago_Public_Schools_-_School_Progress_Reports_SY1718.csv',delimiter=',')
cps_18 = pd.DataFrame
cps_18 = pd.read_csv('../Resources/cityofchicago.org/Chicago_Public_Schools_-_School_Progress_Reports_SY1819.csv',delimiter=',')
dfs = [cps_11, cps_hs_12, cps_es_12, cps_hs_13, cps_es_13, cps_16, cps_17, cps_18]

# %%
headerses = []
for df in dfs:
    print(df.head(0))
    headers = df.columns.tolist()
    headerses.append(headers)
# Out:
# Empty DataFrame
# ...

# %%
headerses
# Out:
# [['School ID',
#   'Name of School',
#   'Elementary, Middle, or High School',
#   'Street Address',
#   'City',
#   'State',
#   'ZIP Code',
#   'Phone Number',
#   'Link ',
#   'Network Manager',
#   'Collaborative Name',
#   'Adequate Yearly Progress Made? ',
#   'Track Schedule',
#   'CPS Performance Policy Status',
#   'CPS Performance Policy Level',
#   'Healthy Schools Certified?',
#   'Safety Icon ',
#   'Safety Score',
#   'Family Involvement Icon',
#   'Family Involvement Score',
#   'Environment Icon ',
#   'Environment Score',
#   'Instruction Icon ',
#   'Instruction Score',
#   'Leaders Icon ',
#   'Leaders Score ',
#   'Teachers Icon ',
#   'Teachers Score',
#   'Parent Engagement Icon ',
#   'Parent Engagement Score',
#   'Parent Environment Icon',
#   'Parent Environment Score',
#   'Average Student Attendance',
#   'Rate of Misconducts (per 100 students) ',
#   'Average Teacher Attendance',
#   'Individualized Education Program Compliance Rate ',
# ...

# %%
# from headerses output, copy and paste column headers for potential study variables
import pandas as pd
cps_11
cps_11 = cps_11(columns = ['School ID', 
'ZIP Code',
'Healthy Schools Certified?', 
'Family Involvement Score', 
'Parent Engagement Score',
'Average Student Attendance', 
'Average Teacher Attendance',
'Graduation Rate %',
'College Enrollment Rate %', 
'Community Area Number',
'Community Area Name']
cps_11
cps_hs_12 = cps_hs_12(columns= ['School ID', 'ZIP',
                                '5-Year Cohort Graduation Rate 2011 - Percent',
                                '5-Year Cohort Graduation Rate 2012 - Percent',
                                'One-Year Dropout Rate 2011 - Percent',
                                'One-Year Dropout Rate 2012 - Percent',
                                'College Enrollment 2011 - Percent',
                                'College Enrollment 2012 - Percent',
                                'College Retention 2009 - Percent',
                                'College Retention 2010 - Percent',
                                'Misconducts Resulting in Suspensions 2011 - Percent',
                                'Misconducts Resulting in Suspensions 2012 - Percent',
                                'Average Days of Suspension 2011',
                                'Average Days of Suspension 2012',
                                'Student Attendance 2011 - Percent',
                                'Student Attendance 2012 - Percent',
                                'Teacher Attendance 2011 - Percent',
                                'Teacher Attendance 2012 - Percent',
                                'Healthy School Certified']
                     )
    
# cps_es_12
['School ID',
'ZIP Code',
'Involved Family',
'Parent-Teacher Partnership',
'Healthy Schools Certification',
'Suspensions Per 100 students 2012',
'Percentage Misconducts Resulting in Suspension 2013',
'Percentage Misconducts Resulting in Suspension 2012',
'Average Length of Suspensions 2013',
'Average Length of Suspension 2012',
'Student Attendance Percentage 2013',
'Student Attendance Percentage 2012',
'Teacher Attendance Percentage 2013',
'Teacher Attendance Percentage 2012',
'Grade 3-8 On-Track Percentage 2013',
'One-Year Drop Out Rate Percentage 2013',
'One-Year Drop Out Rate Percentage 2012']
                
cps_hs_13 = cps_hs_13.columns = ['School ID', 
                        'ZIP Code', 
                                    'Involved Family', 
                                    'Parent-Teacher Partnership', 
                                    'Healthy Schools Certification',
                                    'Creative Schools Certification',
                                    'ACT Spring 2013 Average Grade 11', 
                                    '4-Year Graduation Rate Percentage 2013', 
                                    '4-Year Graduation Rate Percentage 2012',
                                    '5-Year Graduation Rate Percentage 2013',
                                    '5-Year Graduation Rate Percentage 2012',
                                    'College Enrollment Rate Percentage 2013',
                                    'College Enrollment Rate Percentage 2012',
                                    'College Persistence Rate Percentage 2013',
                                    'College Persistence Rate Percentage 2012',
                                    'Suspensions Per 100 2013',
                                    'Suspensions Per 100 2012',
                                    'Student Attendance Percentage 2013',
                                    'Student Attendance Percentage 2012',
                                    'Teacher Attendance Percentage 2013',
                                    'Teacher Attendance Percentage 2012',
                                    'Gr3-8 On-Track Percentage 2013',
                                    'One-Year DropOut Rate Percentage 2013',
                                    'One-Year DropOut Rate Percentage 2012'])
# Out:
#   File "<ipython-input-99-2c5c675e748a>", line 15
#     cps_11
#          ^
# SyntaxError: invalid syntax

# %%
### Rename columns with uniform labels

### Drop unwanted columns/declare DataFrames using only wanted columns

### Merge 
Merge cps_hs_12, cps_es_12, cps_hs_13, cps_es_13, cps_16, cps_17, cps_18 on 'School ID'
Merge the resulting df with cps_11 on 'Neighborhood'
# Out:
#   File "<ipython-input-75-853d11a0a037>", line 6
#     Merge cps_hs_12, cps_es_12, cps_hs_13, cps_es_13, cps_16, cps_17, cps_18 on 'School ID'
#                   ^
# SyntaxError: invalid syntax

# %%
from mpl_toolkits import mplot3d # for 3-d scatter plot (or line chart)
